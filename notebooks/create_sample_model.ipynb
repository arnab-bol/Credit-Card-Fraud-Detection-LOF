# %%
import pandas as pd
import joblib

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import LocalOutlierFactor

# %%
df = pd.read_csv("../dataset/sample_creditcard.csv")

print(df.shape)
df.head()
# Out:
# (1000, 31)
#        Time        V1        V2        V3        V4        V5        V6  \
# 0  155815.0  2.209673 -0.848978 -3.539097 -2.008977  2.411874  2.697310
# 1   57318.0 -0.833781  0.555928  0.376923 -0.814204 -0.683483  0.266157
# 2   51229.0  0.971414 -0.732046  1.030954  0.087852 -0.884327  0.885178
# 3   46332.0  0.803343 -0.277287  0.075839  1.427518 -0.299565 -0.530020
# 4  153216.0  1.641370 -0.675761 -0.658491  0.995062  0.221721  1.594982
#
#          V7        V8        V9  ...       V21       V22       V23       V24  \
# 0 -0.332790  0.470968 -1.135406  ...  0.361712  0.881568 -0.052417  0.767990
# 1 -0.043950  0.414711 -1.643608  ...  0.152280  0.371749 -0.098817 -0.336003
# 2 -0.882762  0.503799  1.034042  ... -0.099659 -0.154111  0.086697 -0.215798
# 3  0.539634 -0.209054 -0.018729  ...  0.139201  0.189511 -0.258111  0.443283
# 4 -0.712119  0.533340  0.715210  ...  0.371946  1.064439  0.048053 -1.650118
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.476852  0.097680 -0.064753 -0.082872   39.80      0
# 1 -0.514888 -0.298047 -0.106999  0.030772   99.99      0
# 2 -0.085046  0.980241 -0.019491  0.005841   65.08      0
# 3  0.677689 -0.289598 -0.005232  0.048534  197.47      0
# 4 -0.295678 -0.459141  0.081518 -0.040502  105.00      0
#
# [5 rows x 31 columns]

# %%
X = df.drop("Class", axis=1)
y = df["Class"]

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
lof = LocalOutlierFactor(
    n_neighbors=20,
    contamination=0.0017,
    novelty=True
)

lof.fit(X_scaled)
# Out:
# LocalOutlierFactor(contamination=0.0017, novelty=True)

# %%
import joblib

joblib.dump(lof, "../models/lof_model_sample.pkl")
# Out:
# ['../models/lof_model_sample.pkl']
